# %% [markdown]
# 22# QUESTION NO=2

# %%
age=17
age=int(input("enter the value:"))
if age>17:
    print("eligible vor vote")
    
else:
    print("not eligible for vote")
# Out:
# enter the value:2
# not eligible for vote

# %% [markdown]
# # QUESTION NO=3

# %%
a=10
b=15
a=int(input("enter the value:"))
if a==10:
    print("this is even number")

elif a==15:
    print("thsi is odd number")
else:
    print("wrong number")
# Out:
# enter the value:15
# thsi is odd number

# %% [markdown]
# # QUESTION NO=4

# %%
a=7
b=49
a=int(input("enter the value a:"))
b=int(input("enter the value b"))
if a%b:
    print("this is divisible")
    
elif a==b:
    print("this is not divisible ")
else:
    ("fail")
# Out:
# enter the value a:7
# enter the value b49
# this is divisible

# %% [markdown]
# # QUESTION NO=5

# %%
num=45
num=int(input("enter the number:"))
if num%5==0:
    print("hello")
else:
    print("bye")
# Out:
# enter the number:45
# hello

# %% [markdown]
# # QUESTION NO=7

# %%
n=int(input("enter the no:"))
print('last digit is:', n%10)
# Out:
# enter the no:45
# last digit is: 5

# %% [markdown]
# # QUESTION NO=8

# %%
a=3
b=5
a=int(input("enter the value:"))
b=int(input("enter the value:"))
if a==b:
    print("this is not divisible")

elif a%b:
    print("this is  divisible")

else:
    print("error")
# Out:
# enter the value:1
# enter the value:1
# this is not divisible

# %% [markdown]
# # QUESTION NO=9

# %%
l=10
b=20
l=int(input("enter the value"))
b=int(input("enter the value:"))
if l*b:
    print("this is square")
else:
    print("this is triangle")
# Out:
# enter the value10
# enter the value:10
# this is square

# %% [markdown]
# # QUESTION NO=10

# %%
a=20
b=10
a=int(input("enter the value1:"))
b=int(input("enter tha value2:"))
if a>b:
    print("this is greater")
    
elif a==b:
    print("this is equal")
else:
    print("this is not required no")
# Out:
# enter the value1:15
# enter tha value2:12
# this is greater

# %% [markdown]
# # QUESTION NO=11

# %%
amt=int(input("enter the ammount:"))
if (amt>0):
    if amt >=1000:
        disc=amt*0.05
elif amt <1000:
    print("not")
else:
    print("faiol")
# Out:
# enter the ammount:2000

# %% [markdown]
# # QUESTION NO=12

# %%
marks=int(input("enter the value:"))
grade=""
if (marks>=90):
    print("A grade")
elif (marks>=80):
    print("B grade")
elif (marks>=70):
    print("C grade")
elif (marks>=60):
    print("D grade")
elif (marks>=50):
    print("E grade")
elif (marks>=40):
    print("F grade")
else:
    ("fail")
# Out:
# enter the value:95
# A grade

# %% [markdown]
# # QUESTION NO=14

# %%
a=int(input("enter the value:")
a==20
if a>20:
    print("per greater than 75")
elif a<20:
    print("per less than 75")
else:
    ("yopu are ill")
# Out:
#   Cell In[69], line 1
#     a=int(input("enter the value:")
#          ^
# SyntaxError: '(' was never closed

# %% [markdown]
# # QUESTION NO=15

# %%
cost_per_unit = 100
quantity = int(input("Enter the quantity of units purchased: "))
total_cost = quantity * cost_per_unit
if total_cost > 1000:
    discount = 0.10 * total_cost
    total_cost -= discount
    print(f"Congratulations! You get a 10% discount.")
    print(f"Total cost after discount: ${total_cost:.2f}")
else:
    print(f"Total cost: ${total_cost:.2f}")
# Out:
# Enter the quantity of units purchased: 25000
# Congratulations! You get a 10% discount.
# Total cost after discount: $2250000.00

# %% [markdown]
# # QUESTION NO=16

# %%
a=4
b=2000,1900,2100
a=int(input("enter tha value1:"))
b=int(input("enter tha value2:"))
if a==4:
    print("this is leap year")
elif a!=4:
    print("this is continue year")
else:
    print("calender issued")
# Out:
# enter tha value1:4
# enter tha value2:4
# this is leap year

# %% [markdown]
# # QUESTION NO=17

# %%
age = int(input("Enter your age: "))
gender = input("Enter your gender (M or F): ").upper()
marital_status = input("Enter your marital status (Y or N): ").upper()
if gender == 'F':
    print("You will work in urban areas.")
elif gender == 'M' and 20 <= age <= 40:
    print("You may work anywhere.")
elif gender == 'M' and 40 <= age <= 60:
    print("You will work in urban areas only.")
else:
    print("ERROR")
# Out:
# Enter your age: 25
# Enter your gender (M or F): m
# Enter your marital status (Y or N): no
# You may work anywhere.

# %% [markdown]
# # QUESTION NO=6

# %%
units = int(input("Enter the number of units: "))
if units <= 100:
    bill_amount = 0
elif units <= 300:
    bill_amount = (units - 100) * 5
elif units > 300:
    bill_amount = 200 * 5 + (units - 300) * 10
    print(f"Total bill amount is Rs.{bill_amount}")
# Out:
# Enter the number of units: 10

# %% [markdown]
# # QUESTION NO=13

# %%
age=10
age=18
age=80
age=int(input("enter tha value:"))
if age==10:
    print("this is child")
    
elif age==18:
    print("this is youngest")
elif age==80:
    print("this is oldest")
else:
    print("new born")
# Out:
# enter tha value:80
# this is oldest

# %% [markdown]
# # QUESTION NO=1

# %%
bonus=0.05
salary=int(input("enter the salary:"))
service=int(input("enter the service:"))
service==5
if service==5:
    print("you are not eligible for 5 discount%")
    
elif service>5:
    ("illigible for 5% discount")
else:
    print("illigible for bonus")
# Out:
# enter the salary:1222
# enter the service:5
# you are not eligible
